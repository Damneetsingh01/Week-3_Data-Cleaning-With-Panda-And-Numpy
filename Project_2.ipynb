# %% [markdown]
# <a href="https://colab.research.google.com/github/Damneetsingh01/Week_3_Data-Cleaning-With-Panda-And-Numpy/blob/main/Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Data cleaning and manipulation using Pandas and Numpy**
# ## Dataset:
# 1. Chipotle.tsv (df)
# #Columns:
#
# * Order Id
# * Quantity
# * Item Name
# * Choice Description
# * Item price
#
#
# ## Chipotle dataset
#
# * Importing the libraries

# %%
# importing libraries
import numpy as np
import pandas as pd

# %% [markdown]
# * Reading the data

# %%
df = pd.read_csv('/content/Project 2 Raw Data.tsv', sep='\t')

# %% [markdown]
# * Raw Data

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# * Copying the dataset To preserve the content of original dataset

# %%
copy_df = df.copy()

# %% [markdown]
# * Data Details

# %%
print(copy_df.head())


print(copy_df.tail())


print(copy_df.shape)


print(copy_df.info())
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# ...

# %% [markdown]
# * Finding the total null values in each columns

# %%
copy_df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %% [markdown]
# * Finding the duplicate values

# %%
duplicates = copy_df.duplicated()
copy_df[duplicates]
# Out:
#       order_id  quantity                            item_name  \
# 238        103         1                        Steak Burrito
# 248        108         1                          Canned Soda
# 297        129         1                        Steak Burrito
# 381        165         1                    Canned Soft Drink
# 484        205         1                         Chicken Bowl
# 567        233         1                    Canned Soft Drink
# 617        254         1                                Chips
# 684        282         1                    Canned Soft Drink
# 773        319         1                         Chicken Bowl
# 908        376         1                        Steak Burrito
# 924        381         1                   Chicken Soft Tacos
# 1003       412         1                        Bottled Water
# 1117       462         1                      Chicken Burrito
# 1203       491         1                      Chicken Burrito
# ...

# %% [markdown]
# * Dropping duplicate values

# %%
copy_df = copy_df.drop_duplicates()

# %% [markdown]
# * Checking again for duplicate values

# %%
check_duplicates = copy_df.duplicated()
copy_df[check_duplicates]
# Out:
# Empty DataFrame
# Columns: [order_id, quantity, item_name, choice_description, item_price]
# Index: []

# %% [markdown]
# * Printing unique 'item_name'

# %%
df['item_name'].unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %% [markdown]
# * Formatting string

# %%
copy_df['item_name'] = copy_df['item_name'].str.replace('-', ' ')

## Printing again unique 'item_name'

copy_df['item_name'].unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl',
#        'Steak Bowl', 'Barbacoa Soft Tacos', 'Veggie Burrito',
#        'Veggie Bowl', 'Steak Crispy Tacos',
#        'Chips and Tomatillo Red Chili Salsa', 'Barbacoa Crispy Tacos',
#        'Veggie Salad Bowl', 'Chips and Roasted Chili Corn Salsa',
#        'Carnitas Soft Tacos', 'Chicken Salad', 'Canned Soft Drink',
#        'Steak Salad Bowl', '6 Pack Soft Drink', 'Bowl', 'Burrito',
#        'Crispy Tacos', 'Carnitas Crispy Tacos', 'Steak Salad',
#        'Chips and Mild Fresh Tomato Salsa', 'Veggie Soft Tacos',
# ...

# %% [markdown]
# * Formatting string

# %%
copy_df['choice_description'] = copy_df['choice_description'].str.strip('[]')

copy_df['choice_description'] = copy_df['choice_description'].str.replace('[', '',).str.replace(']', ',')

copy_df
# Out:
# <ipython-input-15-8573e64e6ffb>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   copy_df['choice_description'] = copy_df['choice_description'].str.replace('[', '',).str.replace(']', ',')
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# ...

# %%
copy_df['item_price'] = copy_df['item_price'].str.replace('$', '')
copy_df.head()
# Out:
# <ipython-input-16-c69cd6759776>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   copy_df['item_price'] = copy_df['item_price'].str.replace('$', '')
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN      2.39
# 1                                         Clementine      3.39
# 2                                              Apple      3.39
# ...

# %% [markdown]
# * Getting more information about the dataset

# %%
copy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4563 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4563 non-null   int64
#  1   quantity            4563 non-null   int64
#  2   item_name           4563 non-null   object
#  3   choice_description  3335 non-null   object
#  4   item_price          4563 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 213.9+ KB

# %% [markdown]
# * Converting to necessary datatype

# %%
copy_df['item_name'] = copy_df['item_name'].astype('string')

copy_df['choice_description'] = copy_df['choice_description'].astype('string')

copy_df['item_price'] = copy_df['item_price'].astype('float')

# %% [markdown]
# * Getting more information about the dataset

# %%
copy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4563 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4563 non-null   int64
#  1   quantity            4563 non-null   int64
#  2   item_name           4563 non-null   string
#  3   choice_description  3335 non-null   string
#  4   item_price          4563 non-null   float64
# dtypes: float64(1), int64(2), string(2)
# memory usage: 213.9 KB

# %% [markdown]
# * Printing the cleaned dataset

# %%
copy_df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                  <NA>        2.39
# ...
